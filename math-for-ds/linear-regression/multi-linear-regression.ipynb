# %% [markdown]
# ## Многомерная линейная регрессия

# %%
# Линейная регрессия с двумя входными переменными
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

df = pd.read_csv("https://bit.ly/2X1HWH7", delimiter=",")

df.to_csv("data.csv", index=False)

df.info()

X = df.values[:, :-1]
Y = df.values[:, -1]

model = LinearRegression()

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)
model.fit(X_train, Y_train)

r2 = model.score(X_test, Y_test)
print(f"r² = {r2}")

a, b = model.coef_
c = model.intercept_

print(f"Угловые коэффициенты = {fit.coef_}")
print(f"Пересечение = {fit.intercept_}")
print(f"z = {fit.intercept_} = {fit.coef_[0]}x + {fit.coef_[1]}y")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 69 entries, 0 to 68
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   x1      69 non-null     int64
#  1   x2      69 non-null     int64
#  2   y       69 non-null     int64
# dtypes: int64(3)
# memory usage: 1.7 KB
# r² = 0.9943152897273624
# Угловые коэффициенты = [2.00672647 3.00203798]
# Пересечение = 20.109432820035963
# z = 20.109432820035963 = 2.0067264725128067x + 3.002037976646693y

# %%
import numpy as np
import matplotlib.pyplot as plt

# Извлечение значений признаков и цели
x_vals = X[:, 0]
y_vals = X[:, 1]
z_vals = Y

# Сетка для построения плоскости регрессии
x_range = np.linspace(x_vals.min(), x_vals.max(), 20)
y_range = np.linspace(y_vals.min(), y_vals.max(), 20)
xx, yy = np.meshgrid(x_range, y_range)
zz = a * xx + b * yy + c

# Визуализация
fig = plt.figure(figsize=(10, 7))
ax = fig.add_subplot(111, projection='3d')

# Точки данных
ax.scatter(x_vals, y_vals, z_vals, color='blue', label='Данные')

# Плоскость регрессии
ax.plot_surface(xx, yy, zz, alpha=0.5, color='red')

# Подписи
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
ax.set_title('Регрессионная плоскость по данным из CSV')

plt.tight_layout()
plt.show()
