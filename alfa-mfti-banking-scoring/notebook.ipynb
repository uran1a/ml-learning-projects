# %%
import pandas as pd

train = pd.read_csv("train_target.csv")
test = pd.read_csv("test_target.csv")

train.info()
train.describe()
train["target"].value_counts(normalize=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000000 entries, 0 to 2999999
# Data columns (total 2 columns):
#  #   Column  Dtype
# ---  ------  -----
#  0   id      int64
#  1   target  int64
# dtypes: int64(2)
# memory usage: 45.8 MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500000 entries, 0 to 499999
# Data columns (total 1 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   id      500000 non-null  int64
# dtypes: int64(1)
# memory usage: 3.8 MB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500000 entries, 0 to 499999
# Data columns (total 1 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   id      500000 non-null  int64
# dtypes: int64(1)
# memory usage: 3.8 MB

# %%
df = pd.read_parquet("train_data/train_data_0.pq")
df.head(10000).to_csv("train_data_0.csv", index=False)

# %%
train_data_0 = pd.read_csv('train_data_0.csv')

train_data_0.head()
train_data_0.info()
train_data_0.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 59 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          10000 non-null  int64
#  1   rn          10000 non-null  int64
#  2   enc_col_0   10000 non-null  int64
#  3   enc_col_1   10000 non-null  int64
#  4   enc_col_2   10000 non-null  int64
#  5   enc_col_3   10000 non-null  int64
#  6   enc_col_4   10000 non-null  int64
#  7   enc_col_5   10000 non-null  int64
#  8   enc_col_6   10000 non-null  int64
#  9   enc_col_7   10000 non-null  int64
#  10  enc_col_8   10000 non-null  int64
#  11  enc_col_9   10000 non-null  int64
#  12  enc_col_10  10000 non-null  int64
#  13  enc_col_11  10000 non-null  int64
#  14  enc_col_12  10000 non-null  int64
#  15  enc_col_13  10000 non-null  int64
#  16  enc_col_14  10000 non-null  int64
#  17  enc_col_15  10000 non-null  int64
#  18  enc_col_16  10000 non-null  int64
# ...
